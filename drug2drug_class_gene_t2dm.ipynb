# %%
import pandas as pd
import numpy as np

# %%
primekg = pd.read_csv('dataverse_files/kg.csv')

host_layer = pd.read_csv('host_layer_data.csv')
drug_data = pd.read_csv('drug_data_14_07.csv')

antibiotics_df = pd.read_csv('antibiotics_list.csv')
# Out:
# /tmp/ipykernel_326218/2665277008.py:1: DtypeWarning: Columns (3,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   primekg = pd.read_csv('dataverse_files/kg.csv')

# %%
gene_listx = host_layer[host_layer['x_type'] == 'gene/protein']['x_name'].to_list()
gene_listy = host_layer[host_layer['y_type'] == 'gene/protein']['y_name'].to_list()

# %%
gene_list = list(set(gene_listx + gene_listy))

# %%
relevant_drugs = primekg[(primekg['x_type'] == 'drug') & (primekg['y_name'].isin(gene_list))].copy()

# %%
relevant_drugs['drug_class'] = np.zeros(len(relevant_drugs))

# %%
relevant_drugs[relevant_drugs['x_name'] == 'Ciprofloxacin']
# Out:
#             relation display_relation  x_index     x_id x_type         x_name  \
# 321263  drug_protein          carrier    14188  DB00537   drug  Ciprofloxacin
# 323522  drug_protein           enzyme    14188  DB00537   drug  Ciprofloxacin
# 328080  drug_protein           target    14188  DB00537   drug  Ciprofloxacin
# 333070  drug_protein           target    14188  DB00537   drug  Ciprofloxacin
# 344434  drug_protein      transporter    14188  DB00537   drug  Ciprofloxacin
#
#         x_source  y_index  y_id        y_type  y_name y_source  drug_class
# 321263  DrugBank     4315   213  gene/protein     ALB     NCBI         0.0
# 323522  DrugBank     3955  1544  gene/protein  CYP1A2     NCBI         0.0
# 328080  DrugBank     4447  3757  gene/protein   KCNH2     NCBI         0.0
# 333070  DrugBank     6976  7153  gene/protein   TOP2A     NCBI         0.0
# 344434  DrugBank     4152  5243  gene/protein   ABCB1     NCBI         0.0

# %%
antibiotics_df.tail(3)
# Out:
#                     Name         Family  \
# 102            Tedizolid  Oxazolidinone
# 103  Ceftaroline fosamil  Cephalosporin
# 104        Solithromycin      Macrolide
#
#                                              Usage Popular Brand Name
# 102                                Skin infections           Sivextro
# 103  Skin infections, community-acquired pneumonia            Teflaro
# 104         Community-acquired bacterial pneumonia          Solithera

# %%
antibiotic_name_list = antibiotics_df['Name'].to_list()

# %%
def drug_class_fxn(row): 
    res = row.str.contains('|'.join(antibiotic_name_list))
    if res['x_name'] == True:
        for_compoundnames = row['x_name'].split(' ')
        index = antibiotic_name_list.index(for_compoundnames[0])
        row['drug_class'] = antibiotics_df.iloc[index,1]

    return row

# %%
filled_drug_class = relevant_drugs.apply(lambda x: drug_class_fxn(x), axis = 1)

# %%
#keeping only those we could succesfully match
filled_drug_class = filled_drug_class[filled_drug_class['drug_class'] != 0]

# %%
filled_drug_class.tail()
# Out:
#             relation display_relation  x_index     x_id x_type         x_name  \
# 345843  drug_protein      transporter    15914  DB01017   drug    Minocycline
# 345908  drug_protein      transporter    14309  DB01137   drug   Levofloxacin
# 345932  drug_protein      transporter    15044  DB11633   drug  Isavuconazole
# 345971  drug_protein      transporter    15443  DB00520   drug    Caspofungin
# 345996  drug_protein      transporter    14309  DB01137   drug   Levofloxacin
#
#         x_source  y_index   y_id        y_type   y_name y_source  \
# 345843  DrugBank    13098  10864  gene/protein  SLC22A7     NCBI
# 345908  DrugBank     5481   6582  gene/protein  SLC22A2     NCBI
# 345932  DrugBank     5481   6582  gene/protein  SLC22A2     NCBI
# 345971  DrugBank    12713   6580  gene/protein  SLC22A1     NCBI
# 345996  DrugBank    12713   6580  gene/protein  SLC22A1     NCBI
#
#              drug_class
# 345843     Tetracycline
# 345908  Fluoroquinolone
# 345932            Azole
# 345971     Echinocandin
# 345996  Fluoroquinolone

# %%
key_classes = drug_data['Drug_Class'].to_list()

# %%
filled_drug_class_key = filled_drug_class[filled_drug_class['drug_class'].str.contains('|'.join(key_classes), case = False)].copy()

# %%
filled_drug_class_key['drug_id'] = np.zeros(len(filled_drug_class_key))

# %%
filled_drug_class_key['drug_type'] = ['drug_class']*len(filled_drug_class_key)

# %%
filled_drug_class_key.head()
# Out:
#             relation display_relation  x_index     x_id x_type  \
# 321260  drug_protein          carrier    14185  DB00512   drug
# 321263  drug_protein          carrier    14188  DB00537   drug
# 321270  drug_protein          carrier    14195  DB00567   drug
# 321309  drug_protein          carrier    14230  DB00759   drug
# 321361  drug_protein          carrier    14279  DB01015   drug
#
#                   x_name  x_source  y_index y_id        y_type y_name  \
# 321260        Vancomycin  DrugBank     4315  213  gene/protein    ALB
# 321263     Ciprofloxacin  DrugBank     4315  213  gene/protein    ALB
# 321270        Cephalexin  DrugBank     4315  213  gene/protein    ALB
# 321309      Tetracycline  DrugBank     4315  213  gene/protein    ALB
# 321361  Sulfamethoxazole  DrugBank     4315  213  gene/protein    ALB
#
#        y_source       drug_class  drug_id   drug_type
# 321260     NCBI     Glycopeptide      0.0  drug_class
# 321263     NCBI  Fluoroquinolone      0.0  drug_class
# 321270     NCBI    Cephalosporin      0.0  drug_class
# 321309     NCBI     Tetracycline      0.0  drug_class
# 321361     NCBI      Sulfonamide      0.0  drug_class

# %%
#using drug_dict from the AMR cleaning notebook for ease of ID assignment
drug_dict = {'carbapenem':'160000', 'diaminopyrimidine':'160001', 'cephalosporin':'160002',
       'tetracycline':'160003', 'fusidane':'160004',
       'lincosamide':'160005', 'sulfonamide':'160006',
       'macrolide':'160007', 'phosphonic acid':'160008',
       'disinfecting agents and antiseptics':'160009',
       'aminoglycoside':'160010', 'glycopeptide':'160011',
       'peptide':'160012', 'fluoroquinolone':'160013',
       'isoniazid-like':'160014', 'penam':'160015', 'rifamycin':'160016',
       'phenicol':'160017', 'glycylcycline':'160018', 'polyamine':'160019',
       'cephamycin':'160020', 'streptogramin A':'160021',
       'aminocoumarin':'160022', 'pyrazine':'160023',
       'nucleoside':'160024', 'streptogramin':'160025',
       'pleuromutilin':'160026', 'elfamycin':'160027',
       'oxazolidinone':'160028', 'nitrofuran':'160029',
       'mupirocin-like':'160030', 'bicyclomycin-like':'160031',
       'nitroimidazole':'160032', 'salicylic acid':'160033',
       'monobactam':'160034', 'penem':'160035', 'sulfone':'160036',
       'thioamide':'160037', 'streptogramin B':'160038',
       'nybomycin-like':'160039', 'oxacephem':'160040'}

# %%
filled_drug_class_key['drug_class'] = filled_drug_class_key['drug_class'].str.lower()

# %%
filled_drug_class_key
# Out:
#             relation display_relation  x_index     x_id x_type  \
# 321260  drug_protein          carrier    14185  DB00512   drug
# 321263  drug_protein          carrier    14188  DB00537   drug
# 321270  drug_protein          carrier    14195  DB00567   drug
# 321309  drug_protein          carrier    14230  DB00759   drug
# 321361  drug_protein          carrier    14279  DB01015   drug
# ...              ...              ...      ...      ...    ...
# 345507  drug_protein      transporter    15425  DB00254   drug
# 345835  drug_protein      transporter    14230  DB00759   drug
# 345843  drug_protein      transporter    15914  DB01017   drug
# 345908  drug_protein      transporter    14309  DB01137   drug
# 345996  drug_protein      transporter    14309  DB01137   drug
#
#                   x_name  x_source  y_index    y_id        y_type   y_name  \
# 321260        Vancomycin  DrugBank     4315     213  gene/protein      ALB
# 321263     Ciprofloxacin  DrugBank     4315     213  gene/protein      ALB
# 321270        Cephalexin  DrugBank     4315     213  gene/protein      ALB
# 321309      Tetracycline  DrugBank     4315     213  gene/protein      ALB
# 321361  Sulfamethoxazole  DrugBank     4315     213  gene/protein      ALB
# ...                  ...       ...      ...     ...           ...      ...
# 345507       Doxycycline  DrugBank    34478  340273  gene/protein    ABCB5
# 345835      Tetracycline  DrugBank    13098   10864  gene/protein  SLC22A7
# 345843       Minocycline  DrugBank    13098   10864  gene/protein  SLC22A7
# 345908      Levofloxacin  DrugBank     5481    6582  gene/protein  SLC22A2
# 345996      Levofloxacin  DrugBank    12713    6580  gene/protein  SLC22A1
#
#        y_source       drug_class  drug_id   drug_type
# 321260     NCBI     glycopeptide      0.0  drug_class
# 321263     NCBI  fluoroquinolone      0.0  drug_class
# 321270     NCBI    cephalosporin      0.0  drug_class
# 321309     NCBI     tetracycline      0.0  drug_class
# 321361     NCBI      sulfonamide      0.0  drug_class
# ...         ...              ...      ...         ...
# 345507     NCBI     tetracycline      0.0  drug_class
# 345835     NCBI     tetracycline      0.0  drug_class
# 345843     NCBI     tetracycline      0.0  drug_class
# 345908     NCBI  fluoroquinolone      0.0  drug_class
# 345996     NCBI  fluoroquinolone      0.0  drug_class
#
# [88 rows x 15 columns]

# %%
filled_drug_class_key['drug_class'] = filled_drug_class_key['drug_class'].replace({'lipoglycopeptide':'glycopeptide', 'amphenicol':'phenicol', 'polypeptide':'peptide'})

#justification
#https://www.msdmanuals.com/home/infections/antibiotics/polypeptides?_gl=1*bqonyv*_up*MQ..*_ga*MTQ5MTM0Mjk0My4xNzg0MTExNDk1*_ga_CJ792HFYYC*czE3ODQxMTE0OTQkbzEkZzAkdDE3ODQxMTE0OTQkajYwJGwwJGgw
#https://bio.libretexts.org/Bookshelves/Microbiology/Microbiology_(Kaiser)/Unit_7%3A_Microbial_Genetics_and_Microbial_Metabolism/19%3A_Review_of_Molecular_Genetics/19.1%3A_Polypeptides_and_Proteins
#https://www.msdvetmanual.com/pharmacology/antibacterial-agents/phenicols-use-in-animals
#https://en.wikipedia.org/wiki/Amphenicol

# %%
#Filling the main dataframe with created IDs
def id_fxn(row):
    row['drug_id'] = drug_dict[row['drug_class']]

    return row

filled_drug_class_key = filled_drug_class_key.apply(lambda x: id_fxn(x), axis = 1)

# %%
#checker
filled_drug_class_key[filled_drug_class_key['drug_id'] == 0]
# Out:
# Empty DataFrame
# Columns: [relation, display_relation, x_index, x_id, x_type, x_name, x_source, y_index, y_id, y_type, y_name, y_source, drug_class, drug_id, drug_type]
# Index: []

# %%
filled_drug_class_key = filled_drug_class_key.groupby(filled_drug_class_key[['drug_class','y_name']].agg(frozenset,axis = 1)).first().reset_index(drop=True)

# %%
filled_drug_class_key
# Out:
#         relation display_relation  x_index     x_id x_type            x_name  \
# 0   drug_protein          carrier    14185  DB00512   drug        Vancomycin
# 1   drug_protein      transporter    14936  DB00199   drug      Erythromycin
# 2   drug_protein           target    15914  DB01017   drug       Minocycline
# 3   drug_protein           target    15914  DB01017   drug       Minocycline
# 4   drug_protein           target    15914  DB01017   drug       Minocycline
# ..           ...              ...      ...      ...    ...               ...
# 70  drug_protein           target    15914  DB01017   drug       Minocycline
# 71  drug_protein           enzyme    14279  DB01015   drug  Sulfamethoxazole
# 72  drug_protein           enzyme    14279  DB01015   drug  Sulfamethoxazole
# 73  drug_protein           enzyme    15452  DB00615   drug         Rifabutin
# 74  drug_protein      transporter    14309  DB01137   drug      Levofloxacin
#
#     x_source  y_index  y_id        y_type   y_name y_source       drug_class  \
# 0   DrugBank     4315   213  gene/protein      ALB     NCBI     glycopeptide
# 1   DrugBank     8458  8647  gene/protein   ABCB11     NCBI        macrolide
# 2   DrugBank      763  5601  gene/protein    MAPK9     NCBI     tetracycline
# 3   DrugBank      902  5599  gene/protein    MAPK8     NCBI     tetracycline
# 4   DrugBank     2275  5598  gene/protein    MAPK7     NCBI     tetracycline
# ..       ...      ...   ...           ...      ...      ...              ...
# 70  DrugBank      373  4843  gene/protein     NOS2     NCBI     tetracycline
# 71  DrugBank     8829     9  gene/protein     NAT1     NCBI      sulfonamide
# 72  DrugBank     6856    10  gene/protein     NAT2     NCBI      sulfonamide
# 73  DrugBank     5292  1555  gene/protein   CYP2B6     NCBI        rifamycin
# 74  DrugBank    12713  6580  gene/protein  SLC22A1     NCBI  fluoroquinolone
#
#    drug_id   drug_type
# 0   160011  drug_class
# 1   160007  drug_class
# 2   160003  drug_class
# 3   160003  drug_class
# 4   160003  drug_class
# ..     ...         ...
# 70  160003  drug_class
# 71  160006  drug_class
# 72  160006  drug_class
# 73  160016  drug_class
# 74  160013  drug_class
#
# [75 rows x 15 columns]

# %%
filled_drug_class_key = filled_drug_class_key[['relation','display_relation','drug_id','drug_type','drug_class','y_index','y_type','y_name']]

# %%
final_drugclass_gene_data = filled_drug_class_key.rename(columns={'drug_id':'x_index','drug_type':'x_type','drug_class':'x_name'})

# %%
final_drugclass_gene_data.to_csv('drugclass_gene_data.csv', index = False)
